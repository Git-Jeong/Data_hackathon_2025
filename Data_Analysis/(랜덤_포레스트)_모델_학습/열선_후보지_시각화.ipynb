# %%
import pandas as pd

# %%
url = './make_file/(최종)_랜덤_포로스트_리스트.csv'

# %%
data = pd.read_csv(url)

# %%
lat_list = data['중점_위도']
lon_list = data['중점_경도']

# %%
import folium

# 지도 중심 설정 (가장 첫 번째 좌표를 기준으로)
map_center = [lat_list[0], lon_list[0]]

# 지도 객체 생성
m = folium.Map(location=map_center, zoom_start=12)

# 위도, 경도 데이터를 기반으로 마커 추가
for lat, lon in zip(lat_list, lon_list):
    folium.Marker([lat, lon]).add_to(m)

# 지도 표시
m.save("./make_file/(최종)_랜덤_포레스트_결과.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21533c4393a173ef64d4884690994c86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21533c4393a173ef64d4884690994c86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21533c4393a173ef64d4884690994c86 = L.map(
#                 &quot;map_21533c4393a173ef64d4884690994c86&quot;,
#                 {
#                     center: [37.5679339, 127.0865742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b217a2b309367a51fedae189c9e717cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b217a2b309367a51fedae189c9e717cc.addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_b0d952034e4a8b7f08e7eee43744a1db = L.marker(
#                 [37.5679339, 127.0865742],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_56629706bd137e1f2ee45dd4ff6b14e0 = L.marker(
#                 [37.53175865, 127.06683975],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_53ac2a282e3e97987261274ca90d4134 = L.marker(
#                 [37.55167395, 127.0933179],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_4c8eb084fa6702f03af4a650fa9138f3 = L.marker(
#                 [37.55099325, 127.09275875],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_25a19301378be1777d32891212749809 = L.marker(
#                 [37.55962835, 127.0890377],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_1cf0b9e50f7b9d97397175fe18ff40dd = L.marker(
#                 [37.55962605, 127.08781505],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_f7992ef18151389091dd7c36933aecf9 = L.marker(
#                 [37.5693462, 127.08835485],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_c8baeba2c1efcdbdac42d7a24279e8a2 = L.marker(
#                 [37.567704899999995, 127.0892449],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_1afcaa1d44550ff2f916d85a18156841 = L.marker(
#                 [37.5700629, 127.0876228],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_1833de62536c15d11f8dc6834c038939 = L.marker(
#                 [37.5693778, 127.08401215],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_857e00917cb12c8572eb9000333b2da9 = L.marker(
#                 [37.56877645, 127.08415245],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_0d0bac49bd88516a030b749332499740 = L.marker(
#                 [37.5616962, 127.08630715],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_641c8c2411398bbfb5507def2ea947dd = L.marker(
#                 [37.560548, 127.08802885],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_aad204e6922c612649084bd950e96ce3 = L.marker(
#                 [37.5600751, 127.0896312],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_a72258959d183c73869806a9beece1f6 = L.marker(
#                 [37.5599191, 127.09173145],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_5bd88c2ae263e346a13e752a98496bbe = L.marker(
#                 [37.55928955, 127.0934379],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_64b5298152c935205c65a6c6430261d5 = L.marker(
#                 [37.55928955, 127.0934379],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_2736a9952a118f5434d40756018b4295 = L.marker(
#                 [37.55953345, 127.0921808],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_dcd4c3c540fe8dacc7807aa20e182595 = L.marker(
#                 [37.5559636, 127.0917919],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
#
#
#             var marker_d6394bd6ee769a670fdccd24bc158a38 = L.marker(
#                 [37.5505376, 127.0963006],
#                 {
# }
#             ).addTo(map_21533c4393a173ef64d4884690994c86);
