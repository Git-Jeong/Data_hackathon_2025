# %%
import pandas as pd

# %%
data = pd.read_csv("./data/서울시 열선 설치 현황_2025.3.csv", encoding="euc-kr")

# %%
data = data.drop(columns='연 번')

# %%
for i in range(len(data)) :
    print(data.loc[i ,'설치구간'])
# Out:
# 명륜길(명륜길 74 ~ 명륜9길 1)
# 사직로1길(행촌동 174-5 ~ 171-35)
# 사직로1다길(행촌동 201-172 ~ 171-120)
# 평창길(평창동 435-2 ~ 평창동 448)
# 평창30길(평창동 66-28 ~ 464-14)
# 홍지문길(구기동 54-13 ~ 40-1)
# 백석동길(창의문로 132 ~ 백석동길 12-1)
# 창덕궁길(창덕궁길 190 ~ 창덕궁5길 40)
# 율곡로19길(율곡로19길 24 ~ 율곡로 19길 68-2)
# 홍지문길(홍지문길 2 ~ 홍지문2길 2)
# 평창20길(평창동 148-16 ~ 평창동 139-5)
# 성균관로 13길(국제고 일대(명륜1가 7-69 ~ 명륜3가 1-1003)
# 명륜10길(명륜9길 3-2 ~ 명륜10길 16)
# 동망산길(숭인동 7-8 ~ 숭인동 24-3)
# 홍지문길(홍지문2길 2 ~ 구기동 41-4)
# 평창21길(평창문화로 99 ~ 평창21길 9-14)
# 평창길(평창길 52 ~ 평창문화로 33)
# 평창4길(평창4길 1 ~ 평창4길 9-1)
# 중림로 2-1 ~ 중림로4길 32(중림로4길)
# 퇴계로6가길32 ~ 소월로 39-1(퇴계로2길, 퇴계로6가길)
# 다산로36길 100(다산로36길)
# 퇴계로68길 24-1 ~ 신당동229-56(장충단로10길)
# 필동로8길 16 ~ 필동로8가길 56(필동로8길, 필동로8가길)
# 퇴계로6길 27 ~ 47(퇴계로6길)
# 동호로15길 40~130-2(동호로15길)
# 동호로11나길 81 ~ 동호로11나길 60(동호로11나길)
# 동호로17길 133 ~ 동호로17길 131-18(동호로17길)
# 퇴계로88다길 37~ 다산로36가길 38(다산로36가길)
# 퇴계로90길 73~퇴계로88가길 48-26(퇴계로90길)
# 동호로5길 19~다산로 32(동호로5길)
# 동호로25가길 21 ~ 동호로25길 46(동호로25가길)
# 동호로25가길 3 ~ 9(동호로25가길)
# 만리재로21길 9 ~ 13(만리재로21길)
# ...
