# %%
import pandas as pd
import folium

# %%
url = "./make_file/DBSCAN_결과.csv"
file_encoding = "UTF-8"

# %%
data = pd.read_csv(url, encoding = file_encoding)

# %%
data.columns
# Out:
# Index(['중점_위도', '중점_경도'], dtype='object')

# %%
# 기본 지도 생성 (초기 위치 설정)
map_center = [data['중점_위도'].mean(), data['중점_경도'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# 데이터의 각 행에 대해 마커 추가
for index, row in data.iterrows():
    folium.Marker([row['중점_위도'], row['중점_경도']]).add_to(m)

# 지도 출력
m.save('./make_file/DBSCAN_결과.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c3da9f32cce71a09dd7985fb9ae560b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c3da9f32cce71a09dd7985fb9ae560b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c3da9f32cce71a09dd7985fb9ae560b = L.map(
#                 &quot;map_5c3da9f32cce71a09dd7985fb9ae560b&quot;,
#                 {
#                     center: [37.560223387499995, 127.09125127321428],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_473f9f509efb014911f3023cfd0d1914 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_473f9f509efb014911f3023cfd0d1914.addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_721c85ee9bf1c704944558834fda0c35 = L.marker(
#                 [37.56010705, 127.09505165],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_e7c665931d6952f0cd27fe7d1e1e67c4 = L.marker(
#                 [37.570070099999995, 127.0882275],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_adb6dad74d3934e31026bb8a56270741 = L.marker(
#                 [37.5672517, 127.0895274],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_00d995f7af2f70a0793be55a3ef7d141 = L.marker(
#                 [37.567704899999995, 127.0892449],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_317631b2a0479c2dcdc1229cb0e428b5 = L.marker(
#                 [37.56866725, 127.0874697],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_dfb21711f37e63857a37849a4899f5ce = L.marker(
#                 [37.57081425, 127.08700785],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_13a1d38c01630b84f4b6ef8e07fb37dc = L.marker(
#                 [37.56727065, 127.08706835],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_ba9b63ce2370962422094473f50205fe = L.marker(
#                 [37.56367935, 127.08830215],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_8359cc955d8ad1fd1d18e312259b9db1 = L.marker(
#                 [37.56783115, 127.08852365],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_7746909a1767ebf5bc77ca1fee37a6f1 = L.marker(
#                 [37.5627897, 127.08807295],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_c64d20e9138488b2e4bea97d33c94101 = L.marker(
#                 [37.5624579, 127.08813665],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_7ab584ba6baf0bd34b426aa74e8efdf2 = L.marker(
#                 [37.56122105, 127.0892465],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_9c7682d286b20f5922e95029596d5844 = L.marker(
#                 [37.56098325, 127.0898844],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_0d5ae3d8690bb568b1ea689d81d2d056 = L.marker(
#                 [37.5593071, 127.09274835],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_36bdf6774511265f6356733e914d97e6 = L.marker(
#                 [37.5598547, 127.09189865],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_152eb06f230f6efc6f428f8ba8837980 = L.marker(
#                 [37.5497707, 127.095337],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_c8dbde77df123846a5ffa6e552902ebe = L.marker(
#                 [37.5545105, 127.09497605],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_ba1992cec14ee6168899277e183cd95f = L.marker(
#                 [37.5534914, 127.09544195],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_ccf0407dc12c7ecfc22123911877b2c6 = L.marker(
#                 [37.5498523, 127.09254595],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9ae560b);
#
#
#             var marker_d39702cb7250277f7e477e554f8b0f3b = L.marker(
#                 [37.54973405, 127.09301025],
#                 {
# }
#             ).addTo(map_5c3da9f32cce71a09dd7985fb9a
