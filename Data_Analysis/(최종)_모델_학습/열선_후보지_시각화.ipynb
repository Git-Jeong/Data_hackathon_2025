# %%
import pandas as pd

# %%
url = './make_file/(최종)_랜덤_포로스트_리스트.scv'

# %%
data = pd.read_csv(url)

# %%
lat_list = data['위도']
lon_list = data['경도']

# %%
import folium

# 지도 중심 설정 (가장 첫 번째 좌표를 기준으로)
map_center = [lat_list[0], lon_list[0]]

# 지도 객체 생성
m = folium.Map(location=map_center, zoom_start=12)

# 위도, 경도 데이터를 기반으로 마커 추가
for lat, lon in zip(lat_list, lon_list):
    folium.Marker([lat, lon]).add_to(m)

# 지도 표시
m.save("./make_file/랜덤_포레스트_결과.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1973a852379a99b4365f0da5ae20ff0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1973a852379a99b4365f0da5ae20ff0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1973a852379a99b4365f0da5ae20ff0 = L.map(
#                 &quot;map_f1973a852379a99b4365f0da5ae20ff0&quot;,
#                 {
#                     center: [37.53175865, 127.06683975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f8076abb5d29c829fab64f31128346d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f8076abb5d29c829fab64f31128346d.addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_e1d027f78a21b50cb0d2150b7f0c8c83 = L.marker(
#                 [37.53175865, 127.06683975],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_1d986debf0d90d8d7c3f24a3ad2e3f62 = L.marker(
#                 [37.570070099999995, 127.0882275],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_b6375eb55b2c16ac3de98dc1165c948f = L.marker(
#                 [37.5693462, 127.08835485],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_7528ec420014691ad65be31212235920 = L.marker(
#                 [37.5700629, 127.0876228],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_e4b177a7074b7da809382e1ccc5e1ecb = L.marker(
#                 [37.57081425, 127.08700785],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_7cb6259b4e0916730de25346127f1419 = L.marker(
#                 [37.57007135, 127.08701855],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_9c0590650a9b698789b36cad05ae33de = L.marker(
#                 [37.54934815, 127.10995105],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_8b8d9cef5debf9627e35e5edb5456f3d = L.marker(
#                 [37.55133735, 127.1110625],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_1d9c43e15fde7b464f0bbdd2ae9a9a7c = L.marker(
#                 [37.5511114, 127.11082225],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_ecd91e572ca3bd801973ada55b43f238 = L.marker(
#                 [37.551279750000006, 127.1102607],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_1759d84b3afab13b37839e518606174e = L.marker(
#                 [37.55111905, 127.11049445],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_b8522e120cf7166d10c2aabba90b22af = L.marker(
#                 [37.5598547, 127.09189865],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_4315b1790875b1c35524486a02add9e2 = L.marker(
#                 [37.5556124, 127.09452675],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_ed514c9337774bffd45dc44b05723f0c = L.marker(
#                 [37.54973405, 127.09301025],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_406525a4a5ae065bbaee3be5709dd16e = L.marker(
#                 [37.54942, 127.09299245],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_778c07860516872e11c2bbd83d4e7747 = L.marker(
#                 [37.54984355, 127.09290805],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             var marker_b5239b84201c07ebea5a3ba6db2415e3 = L.marker(
#                 [37.55168015, 127.06958725],
#                 {
# }
#             ).addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
#
#             tile_layer_8f8076abb5d29c829fab64f31128346d.addTo(map_f1973a852379a99b4365f0da5ae20ff0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
