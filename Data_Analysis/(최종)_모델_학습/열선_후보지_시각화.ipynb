# %%
import pandas as pd

# %%
url = './make_file/(최종)_랜덤_포로스트_리스트.scv'

# %%
data = pd.read_csv(url)

# %%
lat_list = data['위도']
lon_list = data['경도']

# %%
import folium

# 지도 중심 설정 (가장 첫 번째 좌표를 기준으로)
map_center = [lat_list[0], lon_list[0]]

# 지도 객체 생성
m = folium.Map(location=map_center, zoom_start=12)

# 위도, 경도 데이터를 기반으로 마커 추가
for lat, lon in zip(lat_list, lon_list):
    folium.Marker([lat, lon]).add_to(m)

# 지도 표시
m.save("./make_file/랜덤_포레스트_결과.html")

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0677c70a04c0a3e9754bc9ebf3b06f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0677c70a04c0a3e9754bc9ebf3b06f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0677c70a04c0a3e9754bc9ebf3b06f6 = L.map(
#                 &quot;map_f0677c70a04c0a3e9754bc9ebf3b06f6&quot;,
#                 {
#                     center: [37.5679339, 127.0865742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b26884bac1fb47a96de3be87e62bf977 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b26884bac1fb47a96de3be87e62bf977.addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_9f657866846ed03b86451f373174330a = L.marker(
#                 [37.5679339, 127.0865742],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_dbea282eb8e6ffd124535730f9198278 = L.marker(
#                 [37.5306437, 127.07141245],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_190e41b8cf43defda352f881cdadf4df = L.marker(
#                 [37.53233265, 127.08701715],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_7755675b6b65376daed1782748edb347 = L.marker(
#                 [37.5282207, 127.077782],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_e60d5ea40487d69a8ad5101602c5aded = L.marker(
#                 [37.53005425, 127.0823668],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_125fbd998887e5e7f3796ff4e4c64e1b = L.marker(
#                 [37.53823015, 127.0803565],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_32b7459d5fff1b2b4fd51c9b4abf68f0 = L.marker(
#                 [37.5420161, 127.0861187],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_973021a08d3a4a1ba0c42eb477b8479e = L.marker(
#                 [37.54348065, 127.08280475],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_61f48118fd7dc277e1730ccd4070f9d1 = L.marker(
#                 [37.5472791, 127.0897312],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_9efb0973a0ad90ba59a6b2618749f204 = L.marker(
#                 [37.5529704, 127.08013945],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_ef9a0da95e516af5d30778b09b576a16 = L.marker(
#                 [37.53175865, 127.06683975],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_2970ca49fa6fb4e612adfc859d95edbb = L.marker(
#                 [37.55663765, 127.0937784],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_e17463c96421fe7f335d4857bd808c71 = L.marker(
#                 [37.5580285, 127.09184585],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_961e5b42654a28c87d6897baccfcc007 = L.marker(
#                 [37.55099325, 127.09275875],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_32cca031f3b7fcfff080d5de70cb3385 = L.marker(
#                 [37.55962835, 127.0890377],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_b224b245b15a3080e271cabf307f64d6 = L.marker(
#                 [37.5596434, 127.08867665],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_b827085345f75a3c5bd1d9e6b9b33ddf = L.marker(
#                 [37.5697185, 127.0885485],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_747d6daadc8f8e00e2039703aca646bf = L.marker(
#                 [37.5693462, 127.08835485],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_61c3f426c8daa29b351edbab0bd702a2 = L.marker(
#                 [37.567704899999995, 127.0892449],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
#
#
#             var marker_88c7b4d1e1c1d99bc5bcd623bc55d28f = L.marker(
#                 [37.56860985, 127.0884901],
#                 {
# }
#             ).addTo(map_f0677c70a04c0a3e9754bc9ebf3b06f6);
