# %%
get_data = []
location = []
data_gu_code = []

# %%
year = 2018
gu_list = [
    110,  # 종로구
    215,  # 광진구
    680,  # 강남구
    740,  # 강동구
    500,  # 강서구
    620,  # 관악구
    530,  # 구로구
    545,  # 금천구
    350,  # 노원구
    320,  # 도봉구
    230,  # 동대문구
    590,  # 동작구
    440,  # 마포구
    410,  # 서대문구
    650,  # 서초구
    200,  # 성동구
    290,  # 성북구
    710,  # 송파구
    470,  # 양천구
    560,  # 영등포구
    170,  # 용산구
    380,  # 은평구
    140,  # 중구
    260   # 중랑구
]

# %%
import requests
import xml.etree.ElementTree as ET
import json

data_find_test = None

for guGun in gu_list : 
    # URL과 요청 파라미터 설정   
    
    url = "http://apis.data.go.kr/B552061/frequentzoneFreezing/getRestFrequentzoneFreezing?"
    api_key = 'null'
    
    params = { 
        "serviceKey": api_key,
        "searchYearCd": year,  # 해당 년도의 데이터 요청
        "siDo": "11",  # 서울시
        "guGun": guGun,  #  
        "type": "XML",  # 응답 타입 XML
        "numOfRows": "100",  # 한 페이지에 출력될 데이터 개수
        "pageNo": "1"  # 페이지 번호
    }
    
    # API 요청
    response = requests.get(url, params=params)
    

    try : 
            # XML 파싱
        root = ET.fromstring(response.text)
        
        # geom_json 값 추출
        geom_json_str = root.find(".//geom_json").text
        temp_location = root.find(".//sido_sgg_nm").text
        temp_location_code = root.find(".//spot_cd").text
        
        # geom_json 파싱
        geom_data = json.loads(geom_json_str)
        
        # coordinates 값 추출
        coordinates = geom_data["coordinates"]
        
        # 중첩된 리스트를 평탄화 (1차원 리스트로 변환)
        flat_coordinates = [coord for sublist in coordinates for coord in sublist]
        
        # 데이터를 저장
        if temp_location not in location : 
            get_data.append(flat_coordinates)
            location.append(temp_location)
            data_gu_code.append(temp_location_code) 
            data_find_test = True 
        print(f'{year}년도 {guGun}는 성공!!')  
    except : 
        print(f'{year}년도 {guGun}는 Null')
# Out:
# 2018년도 110는 Null
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6571253</afos_fid>
#                 <afos_id>2019079</afos_id>
#                 <bjd_cd>1121510700</bjd_cd>
#                 <spot_cd>11215001</spot_cd>
#                 <sido_sgg_nm>서울특별시 광진구1</sido_sgg_nm>
#                 <spot_nm>서울특별시 광진구 화양동(건대입구역 부근)</spot_nm>
#                 <occrrnc_cnt>3</occrrnc_cnt>
#                 <caslt_cnt>7</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>2</se_dnv_cnt>
#                 <sl_dnv_cnt>4</sl_dnv_cnt>
#                 <wnd_dnv_cnt>1</wnd_dnv_cnt>
#                 <geom_json>{"type":"Polygon","coordinates":[[[127.07292728,37.54129396],[127.07289276,37.54101603],[127.07279052,37.54074879],[127.0726245,37.5405025],[127.07240106,37.54028662],[127.07212881,37.54010946],[127.07181819,37.53997781],[127.07148116,37.53989674],[127.07113065,37.53986937],[127.07078015,37.53989674],[127.07044311,37.53997781],[127.0701325,37.54010946],[127.06986024,37.54028662],[127.06963681,37.5405025],[127.06947078,37.54074879],[127.06936855,37.54101603],[127.06933402,37.54129396],[127.06936855,37.54157188],[127.06947078,37.54183911],[127.06963681,37.5420854],[127.06986024,37.54230127],[127.0701325,37.54247844],[127.07044311,37.54261008],[127.07078015,37.54269114],[127.07113065,37.54271852],[127.07148116,37.54269114],[127.07181819,37.54261008],[127.07212881,37.54247844],[127.07240106,37.54230127],[127.0726245,37.5420854],[127.07279052,37.54183911],[127.07289276,37.54157188],[127.07292728,37.54129396]]]}</geom_json>
#                 <lo_crd>127.071130654057</lo_crd>
#                 <la_crd>37.541293955253</la_crd>
#             </item>
#         </items>
#         <totalCount>1</totalCount>
#         <numOfRows>1</numOfRows>
#         <pageNo>1</pageNo>
#     </body>
# </response>
#
# 2018년도 215는 성공!!
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6571254</afos_fid>
#                 <afos_id>2019079</afos_id>
#                 <bjd_cd>1168010400</bjd_cd>
#                 <spot_cd>11680001</spot_cd>
#                 <sido_sgg_nm>서울특별시 강남구1</sido_sgg_nm>
#                 <spot_nm>서울특별시 강남구 청담동(영동대교남단삼거리도 부근)</spot_nm>
#                 <occrrnc_cnt>5</occrrnc_cnt>
#                 <caslt_cnt>9</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>0</se_dnv_cnt>
#                 <sl_dnv_cnt>9</sl_dnv_cnt>
#                 <wnd_dnv_cnt>0</wnd_dnv_cnt>
#                 <geom_json>{"type":"Polygon","coordinates":[[[127.05398709,37.52466577],[127.05395257,37.52438778],[127.05385033,37.52412048],[127.0536843,37.52387413],[127.05346087,37.52365821],[127.05318861,37.523481],[127.052878,37.52334933],[127.05254096,37.52326824],[127.05219046,37.52324086],[127.05183995,37.52326824],[127.05150292,37.52334933],[127.0511923,37.523481],[127.05092005,37.52365821],[127.05069661,37.52387413],[127.05053059,37.52412048],[127.05042835,37.52438778],[127.05039383,37.52466577],[127.05042835,37.52494375],[127.05053059,37.52521105],[127.05069661,37.52545739],[127.05092005,37.52567331],[127.0511923,37.52585051],[127.05150292,37.52598218],[127.05183995,37.52606327],[127.05219046,37.52609064],[127.05254096,37.52606327],[127.052878,37.52598218],[127.05318861,37.52585051],[127.05346087,37.52567331],[127.0536843,37.52545739],[127.05385033,37.52521105],[127.05395257,37.52494375],[127.05398709,37.52466577]]]}</geom_json>
#                 <lo_crd>127.052190456925</lo_crd>
#                 <la_crd>37.524665766713</la_crd>
#             </item>
#             <item>
#                 <afos_fid>6571191</afos_fid>
#                 <afos_id>2019079</afos_id>
#                 <bjd_cd>1168010100</bjd_cd>
#                 <spot_cd>11680002</spot_cd>
#                 <sido_sgg_nm>서울특별시 강남구2</sido_sgg_nm>
#                 <spot_nm>서울특별시 강남구 역삼동(뱅뱅사거리 부근)</spot_nm>
#                 <occrrnc_cnt>3</occrrnc_cnt>
#                 <caslt_cnt>4</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>2</se_dnv_cnt>
#                 <sl_dnv_cnt>2</sl_dnv_cnt>
#                 <wnd_dnv_cnt>0</wnd_dnv_cnt>
#                 <geom_json>{"type":"Polygon","coordinates":[[[127.03340563,37.48955917],[127.03337111,37.48928106],[127.03326887,37.48901363],[127.03310284,37.48876717],[127.03287941,37.48855114],[127.03260715,37.48837385],[127.03229654,37.48824211],[127.0319595,37.48816099],[127.031609,37.4881336],[127.03125849,37.48816099],[127.03092146,37.48824211],[127.03061084,37.48837385],[127.03033859,37.48855114],[127.03011515,37.48876717],[127.02994913,37.48901363],[127.02984689,37.48928106],[127.02981237,37.48955917],[127.02984689,37.48983729],[127.02994913,37.49010471],[127.03011515,37.49035117],[127.03033859,37.49056719],[127.03061084,37.49074448],[127.03092146,37.49087621],[127.03125849,37.49095733],[127.031609,37.49098472],[127.0319595,37.49095733],[127.03229654,37.49087621],[127.03260715,37.49074448],[127.03287941,37.49056719],[127.03310284,37.49035117],[127.03326887,37.49010471],[127.03337111,37.48983729],[127.03340563,37.48955917]]]}</geom_json>
#                 <lo_crd>127.031608997958</lo_crd>
#                 <la_crd>37.489559173918</la_crd>
#             </item>
#         </items>
#         <totalCount>2</totalCount>
#         <numOfRows>2</numOfRows>
#         <pageNo>1</pageNo>
#     </body>
# </response>
#
# 2018년도 680는 성공!!
# 2018년도 740는 Null
# 2018년도 500는 Null
# 2018년도 620는 Null
# 2018년도 530는 Null
# 2018년도 545는 Null
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6571259</afos_fid>
#                 <afos_id>2019079</afos_id>
#                 <bjd_cd>1135010600</bjd_cd>
#                 <spot_cd>11350001</spot_cd>
#                 <sido_sgg_nm>서울특별시 노원구1</sido_sgg_nm>
#                 <spot_nm>서울특별시 노원구 중계동(대진여고앞 부근)</spot_nm>
#                 <occrrnc_cnt>3</occrrnc_cnt>
#                 <caslt_cnt>4</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>1</se_dnv_cnt>
#                 <sl_dnv_cnt>3</sl_dnv_cnt>
#                 <wnd_dnv_cnt>0</wnd_dnv_cnt>
#                 <geom_json>{"type":"Polygon","coordinates":[[[127.06772332,37.6460744],[127.0676888,37.64579687],[127.06758656,37.64553],[127.06742053,37.64528406],[127.0671971,37.64506848],[127.06692484,37.64489157],[127.06661423,37.6447601],[127.06627719,37.64467915],[127.06592669,37.64465182],[127.06557618,37.64467915],[127.06523915,37.6447601],[127.06492853,37.64489157],[127.06465628,37.64506848],[127.06443284,37.64528406],[127.06426682,37.64553],[127.06416458,37.64579687],[127.06413006,37.6460744],[127.06416458,37.64635193],[127.06426682,37.64661879],[127.06443284,37.64686473],[127.06465628,37.6470803],[127.06492853,37.64725721],[127.06523915,37.64738867],[127.06557618,37.64746962],[127.06592669,37.64749696],[127.06627719,37.64746962],[127.06661423,37.64738867],[127.06692484,37.64725721],[127.0671971,37.6470803],[127.06742053,37.64686473],[127.06758656,37.64661879],[127.0676888,37.64635193],[127.06772332,37.6460744]]]}</geom_json>
#                 <lo_crd>127.065926687468</lo_crd>
#                 <la_crd>37.646074399415</la_crd>
#             </item>
#         </items>
#         <totalCount>1</totalCount>
#         <numOfRows>1</numOfRows>
#         <pageNo>1</pageNo>
#     </body>
# </response>
#
# 2018년도 350는 성공!!
# 2018년도 320는 Null
# 2018년도 230는 Null
# 2018년도 590는 Null
# 2018년도 440는 Null
# 2018년도 410는 Null
# 2018년도 650는 Null
# 2018년도 200는 Null
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6571226</afos_fid>
#                 <afos_id>2019079</afos_id>
#                 <bjd_cd>1129013300</bjd_cd>
#                 <spot_cd>11290001</spot_cd>
#                 <sido_sgg_nm>서울특별시 성북구1</sido_sgg_nm>
#                 <spot_nm>서울특별시 성북구 정릉동(아리랑로터리정릉길진 부근)</spot_nm>
#                 <occrrnc_cnt>4</occrrnc_cnt>
#                 <caslt_cnt>5</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>2</se_dnv_cnt>
#                 <sl_dnv_cnt>2</sl_dnv_cnt>
#                 <wnd_dnv_cnt>1</wnd_dnv_cnt>
#                 <geom_json>{"type":"Polygon","coordinates":[[[127.01402264,37.60414461],[127.01398812,37.60386692],[127.01388588,37.6035999],[127.01371985,37.60335382],[127.01349642,37.60313812],[127.01322416,37.6029611],[127.01291355,37.60282957],[127.01257651,37.60274857],[127.01222601,37.60272122],[127.0118755,37.60274857],[127.01153847,37.60282957],[127.01122785,37.6029611],[127.0109556,37.60313812],[127.01073216,37.60335382],[127.01056614,37.6035999],[127.0104639,37.60386692],[127.01042938,37.60414461],[127.0104639,37.60442229],[127.01056614,37.6046893],[127.01073216,37.60493538],[127.0109556,37.60515107],[127.01122785,37.60532809],[127.01153847,37.60545962],[127.0118755,37.60554061],[127.01222601,37.60556796],[127.01257651,37.60554061],[127.01291355,37.60545962],[127.01322416,37.60532809],[127.01349642,37.60515107],[127.01371985,37.60493538],[127.01388588,37.6046893],[127.01398812,37.60442229],[127.01402264,37.60414461]]]}</geom_json>
#                 <lo_crd>127.012226007026</lo_crd>
#                 <la_crd>37.604144605290</la_crd>
#             </item>
#         </items>
#         <totalCount>1</totalCount>
#         <numOfRows>1</numOfRows>
#         <pageNo>1</pageNo>
#     </body>
# </response>
#
# 2018년도 290는 성공!!
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6571213</afos_fid>
#                 <afos_id>2019079</afos_id>
#                 <bjd_cd>1171011400</bjd_cd>
#                 <spot_cd>11710001</spot_cd>
#                 <sido_sgg_nm>서울특별시 송파구1</sido_sgg_nm>
#                 <spot_nm>서울특별시 송파구 마천동(샬롬빌딩 부근)</spot_nm>
#                 <occrrnc_cnt>3</occrrnc_cnt>
#                 <caslt_cnt>4</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>0</se_dnv_cnt>
#                 <sl_dnv_cnt>3</sl_dnv_cnt>
#                 <wnd_dnv_cnt>1</wnd_dnv_cnt>
#                 <geom_json>{"type":"Polygon","coordinates":[[[127.15004333,37.50133021],[127.15000881,37.50105214],[127.14990657,37.50078476],[127.14974054,37.50053833],[127.14951711,37.50032234],[127.14924485,37.50014508],[127.14893424,37.50001336],[127.1485972,37.49993225],[127.1482467,37.49990486],[127.14789619,37.49993225],[127.14755916,37.50001336],[127.14724854,37.50014508],[127.14697629,37.50032234],[127.14675285,37.50053833],[127.14658683,37.50078476],[127.14648459,37.50105214],[127.14645007,37.50133021],[127.14648459,37.50160828],[127.14658683,37.50187566],[127.14675285,37.50212208],[127.14697629,37.50233807],[127.14724854,37.50251533],[127.14755916,37.50264704],[127.14789619,37.50272815],[127.1482467,37.50275554],[127.1485972,37.50272815],[127.14893424,37.50264704],[127.14924485,37.50251533],[127.14951711,37.50233807],[127.14974054,37.50212208],[127.14990657,37.50187566],[127.15000881,37.50160828],[127.15004333,37.50133021]]]}</geom_json>
#                 <lo_crd>127.148246697528</lo_crd>
#                 <la_crd>37.501330211321</la_crd>
#             </item>
#         </items>
#         <totalCount>1</totalCount>
#         <numOfRows>1</numOfRows>
#         <pageNo>1</pageNo>
#     </body>
# </response>
#
# 2018년도 710는 성공!!
# 2018년도 470는 Null
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6571217</afos_fid>
#                 <afos_id>2019079</afos_id>
#                 <bjd_cd>1156011800</bjd_cd>
#                 <spot_cd>11560001</spot_cd>
#                 <sido_sgg_nm>서울특별시 영등포구1</sido_sgg_nm>
#                 <spot_nm>서울특별시 영등포구 도림동(영등포역고가차도남측 부근)</spot_nm>
#                 <occrrnc_cnt>4</occrrnc_cnt>
#                 <caslt_cnt>4</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>3</se_dnv_cnt>
#                 <sl_dnv_cnt>1</sl_dnv_cnt>
#                 <wnd_dnv_cnt>0</wnd_dnv_cnt>
#                 <geom_json>{"type":"Polygon","coordinates":[[[126.91040414,37.51346103],[126.91036962,37.513183],[126.91026738,37.51291566],[126.91010135,37.51266927],[126.90987792,37.51245332],[126.90960566,37.51227608],[126.90929505,37.51214439],[126.90895801,37.51206329],[126.90860751,37.51203591],[126.908257,37.51206329],[126.90791997,37.51214439],[126.90760935,37.51227608],[126.9073371,37.51245332],[126.90711366,37.51266927],[126.90694764,37.51291566],[126.9068454,37.513183],[126.90681088,37.51346103],[126.9068454,37.51373905],[126.90694764,37.51400639],[126.90711366,37.51425277],[126.9073371,37.51446872],[126.90760935,37.51464595],[126.90791997,37.51477764],[126.908257,37.51485873],[126.90860751,37.51488612],[126.90895801,37.51485873],[126.90929505,37.51477764],[126.90960566,37.51464595],[126.90987792,37.51446872],[126.91010135,37.51425277],[126.91026738,37.51400639],[126.91036962,37.51373905],[126.91040414,37.51346103]]]}</geom_json>
#                 <lo_crd>126.908607507631</lo_crd>
#                 <la_crd>37.513461025207</la_crd>
#             </item>
#         </items>
#         <totalCount>1</totalCount>
#         <numOfRows>1</numOfRows>
#         <pageNo>1</pageNo>
#     </body>
# </response>
#
# 2018년도 560는 성공!!
# 2018년도 170는 Null
# 2018년도 380는 Null
# 2018년도 140는 Null
# 2018년도 260는 Null

# %%
import pandas as pd

# %%
if(data_find_test) :
    data = pd.DataFrame({'지역' : location, '법정동코드' : data_gu_code, '사고위치' : get_data})
    data.index = data.index + 1
    file = f'{year}_seoul_icy_road_accident.csv'
    data.to_csv(file)
    print(f'{file} 파일 생성 성공')
    data_find_test = False
# Out:
# 2018_seoul_icy_road_accident.csv 파일 생성 성공
