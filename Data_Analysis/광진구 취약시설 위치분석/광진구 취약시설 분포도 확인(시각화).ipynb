# %%
import pandas as pd
import folium
from folium.plugins import HeatMap
import branca.colormap as cm

# %%
# 데이터 불러오기
gwangjin = pd.read_csv('./make_file/광진구_모든_시설의_위치.csv', index_col=0)
gwangjin['시설_구분'].value_counts()
# Out:
# 시설_구분
# 어린이집    71
# 복지센터    60
# 학교      46
# 아동센터    13
# Name: count, dtype: int64

# %%
# gwangjin['시설_구분'] 컬러맵을 범주에 맞게 설정
category_colors = {
    '어린이집': '#FFA500',  # 주황색
    '복지센터': '#1E90FF',  # 파란색
    '학교': '#32CD32',      # 초록색
    '아동센터': '#FFD700'   # 노란색
}

# %%
import folium
from folium.plugins import HeatMap
import branca.colormap as cm  
 
# 광진구 중심 좌표 설정
gwangjin_center = [37.5374, 127.1232] 
# 기본 지도 설정 (광진구 중심)
m = folium.Map(location=gwangjin_center, zoom_start=12) 
  
# 히트맵 데이터 준비
heat_data = [[row['위도'], row['경도']] for _, row in gwangjin.iterrows()]

# 히트맵 추가
HeatMap(heat_data).add_to(m)

# 범주별 색상 맵 (Branca)
colormap = cm.linear.Set1_09.scale(0, len(gwangjin['시설_구분'].unique()))
colormap.caption = '시설 구분'
colormap.add_to(m)

# HTML로 지도 저장
m.save('./make_file/광진구_시설_분포.html')

# 마커 아이콘 
for _, row in gwangjin.iterrows(): 
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=row['시설_이름']
    ).add_to(m)

# HTML로 지도 저장
m.save('./make_file/광진구_시설_분포(마커).html')

# 지도 출력
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3efdbee5a2affae724d59e2aea87efdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3efdbee5a2affae724d59e2aea87efdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3efdbee5a2affae724d59e2aea87efdd = L.map(
#                 &quot;map_3efdbee5a2affae724d59e2aea87efdd&quot;,
#                 {
#                     center: [37.5374, 127.1232],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_323f18d427dbc4182067f6e9a1ced2fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_323f18d427dbc4182067f6e9a1ced2fa.addTo(map_3efdbee5a2affae724d59e2aea87efdd);
#
#
#             var heat_map_bf03a66f56b3216386410ecc02525904 = L.heatLayer(
#                 [[37.54992721317203, 127.0872728484992], [37.5355505392486, 127.074606675947], [37.5661168883261, 127.088935243662], [37.5450730890035, 127.0981665329], [37.5335136376514, 127.063363038023], [37.563885631132, 127.089453247136], [37.5424939226997, 127.087341127698], [37.5428059919186, 127.079217019013], [37.5320190144575, 127.089587144011], [37.5472972737522, 127.101808707054], [37.5305298330056, 127.085711597685], [37.54045812903372, 127.10141469495024], [37.5411638987574, 127.082537416626], [37.5530165928479, 127.072867690484], [37.5331471248437, 127.089511558448], [37.5661087807112, 127.080124566887], [37.56522319533774, 127.08260357000786], [37.550169835637, 127.072222139803], [37.5370213034069, 127.0796182230381], [37.558260799708094, 127.08443728277568], [37.56707851619092, 127.088582099365], [37.5442656969