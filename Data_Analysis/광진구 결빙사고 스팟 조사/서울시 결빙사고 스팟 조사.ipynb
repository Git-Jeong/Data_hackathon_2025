# %%
get_data = []
location = []
data_gu_code = []

# %%
year = [2016, 2017, 2018, 2019, 2020]
gu_list = [
    110,  # 종로구
    215,  # 광진구
    680,  # 강남구
    740,  # 강동구
    500,  # 강서구
    620,  # 관악구
    530,  # 구로구
    545,  # 금천구
    350,  # 노원구
    320,  # 도봉구
    230,  # 동대문구
    590,  # 동작구
    440,  # 마포구
    410,  # 서대문구
    650,  # 서초구
    200,  # 성동구
    290,  # 성북구
    710,  # 송파구
    470,  # 양천구
    560,  # 영등포구
    170,  # 용산구
    380,  # 은평구
    140,  # 중구
    260   # 중랑구
]

# %%
import pandas as pd

# %%
api_key_url = '../API KEY/API_KEYS.xlsx'
open_api_key_file = pd.read_excel(api_key_url)
 
open_api_key_file['사이트'].value_counts()

get_api_key = open_api_key_file[open_api_key_file['사이트'] == '공공데이터'].values[0][1]

# %%
import requests
import xml.etree.ElementTree as ET
import json

data_find_test = None

for year in year :
    for guGun in gu_list : 
        # URL과 요청 파라미터 설정   
        
        url = "http://apis.data.go.kr/B552061/frequentzoneFreezing/getRestFrequentzoneFreezing?"
        api_key = get_api_key
        
        params = { 
            "serviceKey": api_key,
            "searchYearCd": year,  # 해당 년도의 데이터 요청
            "siDo": "11",  # 서울시
            "guGun": guGun,  #  
            "type": "XML",  # 응답 타입 XML
            "numOfRows": "100",  # 한 페이지에 출력될 데이터 개수
            "pageNo": "1"  # 페이지 번호
        }
        
        # API 요청
        response = requests.get(url, params=params)
        

        try : 
                # XML 파싱
            root = ET.fromstring(response.text)
            
            # geom_json 값 추출
            geom_json_str = root.find(".//geom_json").text
            temp_location = root.find(".//sido_sgg_nm").text
            temp_location_code = root.find(".//spot_cd").text
            
            # geom_json 파싱
            geom_data = json.loads(geom_json_str)
            
            # coordinates 값 추출
            coordinates = geom_data["coordinates"]
            
            # 중첩된 리스트를 평탄화 (1차원 리스트로 변환)
            flat_coordinates = [coord for sublist in coordinates for coord in sublist]
            
            # 데이터를 저장
            if temp_location not in location : 
                get_data.append(flat_coordinates)
                location.append(temp_location)
                data_gu_code.append(temp_location_code) 
                data_find_test = True 
            print(f'{year}년도 {guGun}는 성공!!')  
        except : 
            print(f'{year}년도 {guGun}는 Null') 

        if(data_find_test) :
            data = pd.DataFrame({'지역' : location, '법정동코드' : data_gu_code, '사고위치' : get_data})
            data.index = data.index + 1
            file = f'./make_file/{year}_seoul_icy_road_accident.csv'
            data.to_csv(file)
            print(f'{file} 파일 생성 성공')
            data_find_test = False
# Out:
# 2016년도 110는 Null
# 2016년도 215는 Null
# 2016년도 680는 Null
# 2016년도 740는 Null
# 2016년도 500는 Null
# 2016년도 620는 Null
# 2016년도 530는 Null
# 2016년도 545는 Null
# 2016년도 350는 Null
# 2016년도 320는 Null
# 2016년도 230는 Null
# 2016년도 590는 Null
# 2016년도 440는 Null
# 2016년도 410는 Null
# 2016년도 650는 Null
# 2016년도 200는 Null
# 2016년도 290는 Null
# 2016년도 710는 Null
# 2016년도 470는 Null
# 2016년도 560는 Null
# 2016년도 170는 Null
# 2016년도 380는 Null
# 2016년도 140는 Null
# 2016년도 260는 Null
# 2017년도 110는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 215는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 680는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 740는 Null
# 2017년도 500는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 620는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 530는 Null
# 2017년도 545는 Null
# 2017년도 350는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 320는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 230는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 590는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 440는 Null
# 2017년도 410는 Null
# 2017년도 650는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 200는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 290는 Null
# 2017년도 710는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 470는 Null
# 2017년도 560는 Null
# 2017년도 170는 Null
# 2017년도 380는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 140는 성공!!
# ./data/2017_seoul_icy_road_accident.csv 파일 생성 성공
# 2017년도 260는 Null
# 2018년도 110는 Null
# 2018년도 215는 성공!!
# 2018년도 680는 성공!!
# 2018년도 740는 Null
# 2018년도 500는 Null
# 2018년도 620는 Null
# 2018년도 530는 Null
# 2018년도 545는 Null
# 2018년도 350는 성공!!
# 2018년도 320는 Null
# 2018년도 230는 Null
# 2018년도 590는 Null
# 2018년도 440는 Null
# 2018년도 410는 Null
# 2018년도 650는 Null
# 2018년도 200는 Null
# 2018년도 290는 성공!!
# ./data/2018_seoul_icy_road_accident.csv 파일 생성 성공
# 2018년도 710는 성공!!
# 2018년도 470는 Null
# 2018년도 560는 성공!!
# ./data/2018_seoul_icy_road_accident.csv 파일 생성 성공
# 2018년도 170는 Null
# 2018년도 380는 Null
# 2018년도 140는 Null
# 2018년도 260는 Null
# 2019년도 110는 Null
# 2019년도 215는 Null
# 2019년도 680는 성공!!
# 2019년도 740는 Null
# 2019년도 500는 Null
# 2019년도 620는 Null
# 2019년도 530는 Null
# 2019년도 545는 Null
# 2019년도 350는 성공!!
# 2019년도 320는 Null
# 2019년도 230는 Null
# 2019년도 590는 Null
# 2019년도 440는 Null
# 2019년도 410는 Null
# 2019년도 650는 Null
# 2019년도 200는 Null
# 2019년도 290는 성공!!
# 2019년도 710는 Null
# 2019년도 470는 Null
# 2019년도 560는 Null
# 2019년도 170는 Null
# 2019년도 380는 Null
# 2019년도 140는 Null
# 2019년도 260는 Null
# 2020년도 110는 Null
# 2020년도 215는 Null
# 2020년도 680는 성공!!
# 2020년도 740는 Null
# 2020년도 500는 Null
# 2020년도 620는 Null
# 2020년도 530는 Null
# 2020년도 545는 Null
# 2020년도 350는 성공!!
# 2020년도 320는 Null
# 2020년도 230는 Null
# 2020년도 590는 Null
# 2020년도 440는 Null
# 2020년도 410는 Null
# 2020년도 650는 Null
# 2020년도 200는 Null
# 2020년도 290는 성공!!
# 2020년도 710는 Null
# 2020년도 470는 Null
# 2020년도 560는 Null
# 2020년도 170는 Null
# 2020년도 380는 Null
# 2020년도 140는 Null
# 2020년도 260는 Null
